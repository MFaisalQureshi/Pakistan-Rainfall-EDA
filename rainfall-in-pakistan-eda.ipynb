# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/rainfall-in-pakistan/Rainfall_1901_2016_PAK.csv

# %%
data=pd.read_csv('/kaggle/input/rainfall-in-pakistan/Rainfall_1901_2016_PAK.csv')
data
# Out:
#       Rainfall - (MM)   Year      Month
# 0            40.42580   1901    January
# 1            12.30220   1901   February
# 2            25.51190   1901      March
# 3            14.29420   1901      April
# 4            38.30460   1901        May
# ...               ...    ...        ...
# 1387         60.60610   2016     August
# 1388         13.76940   2016  September
# 1389          1.07552   2016    October
# 1390          2.88480   2016   November
# 1391          7.82298   2016   December
#
# [1392 rows x 3 columns]

# %%
data.shape
# Out:
# (1392, 3)

# %%
data.columns
# Out:
# Index(['Rainfall - (MM)', ' Year', 'Month'], dtype='object')

# %%
data.rename(columns={'Rainfall - (MM)':'Rainfall-(mm)',' Year':'Year'},inplace=True)
data.columns
# Out:
# Index(['Rainfall-(mm)', 'Year', 'Month'], dtype='object')

# %%
data.head(10)
# Out:
#    Rainfall-(mm)  Year      Month
# 0       40.42580  1901    January
# 1       12.30220  1901   February
# 2       25.51190  1901      March
# 3       14.29420  1901      April
# 4       38.30460  1901        May
# 5       12.88130  1901       June
# 6       68.09300  1901       July
# 7       16.58360  1901     August
# 8       13.33910  1901  September
# 9        3.10757  1901    October

# %% [markdown]
# # Analysis and Visualize Rainfall During Year 2000 to 2016

# %%
plt.figure(figsize=(15,8))
graph=px.bar(data.loc[(data.Year>=1990)],x="Year",y="Rainfall-(mm)",hover_name='Month',color='Month',title='Rainfall During 2000 to 2016')
graph.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6f11bfe6-42da-413e-a7b7-187b0748b998" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f11bfe6-42da-413e-a7b7-187b0748b998")) {                    Plotly.newPlot(                        "6f11bfe6-42da-413e-a7b7-187b0748b998",                        [{"alignmentgroup": "True", "hovertemplate": "<b>%{hovertext}</b><br><br>Month=January<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "hovertext": ["January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January", "January"], "legendgroup": "January", "marker": {"color": "#636efa"}, "name": "January", "offsetgroup": "January", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], "xaxis": "x", "y": [37.5664, 23.5797, 53.9661, 29.6088, 19.5592, 9.26441, 27.9485, 23.2765, 32.6726, 32.9247, 19.311, 3.98006, 8.26817, 12.9862, 41.6249, 37.2572, 28.5383, 3.0348, 43.5298, 34.3593, 9.37983, 11.1674, 21.7436, 12.3896, 11.4887, 16.3651, 16.1749], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "<b>%{hovertext}</b><br><br>Month=February<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "hovertext": ["February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February", "February"], "legendgroup": "February", "marker": {"color": "#EF553B"}, "name": "February", "offsetgroup": "February", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], "xaxis": "x", "y": [57.1569, 42.6492, 29.1195, 15.8378, 29.1929, 30.1864, 40.7236, 5.92436, 39.6264, 36.1811, 14.2357, 7.90859, 24.8489, 62.8046, 15.2825, 58.6492, 15.7051, 49.8075, 13.6756, 33.2747, 31.8993, 58.0763, 19.6736, 46.5909, 22.7004, 30.9235, 8.36436], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "<b>%{hovertext}</b><br><br>Month=March<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "hovertext": ["March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March", "March"], "legendgroup": "March", "marker": {"color": "#00cc96"}, "name": "March", "offsetgroup": "March", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], "xaxis": "x", "y": [35.7753, 42.4584, 38.7504, 32.1792, 23.597, 23.1022, 44.5704, 38.9486, 37.2368, 23.3168, 8.70368, 16.1858, 23.0497, 31.7944, 5.57348, 40.9373, 27.5402, 63.3527, 2.83751, 28.2929, 20.63, 30.0545, 22.278, 53.8636, 55.8119, 70.0159, 57.6948], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "<b>%{hovertext}</b><br><br>Month=April<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "hovertext": ["April", "April", "April", "April", "April", "April", "April", "April", "April", "April", "April", "April", "April", ...

# %% [markdown]
# # Analysis and Visualize Rainfall During Year 2000 to 2016 Using Animation Bar

# %%
graph=px.bar(data.loc[(data.Year>=2000)],x="Year",y="Rainfall-(mm)",color="Month",title='Rainfall During 2000 to 2016 Using Animation'
              ,animation_frame="Year",animation_group="Month",log_x=True,range_x=[1999,2017], range_y=[0,400])
graph.show()
# Out:
# <div>                            <div id="be5c6e42-6b05-420d-b641-db9ab4e5e5f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be5c6e42-6b05-420d-b641-db9ab4e5e5f7")) {                    Plotly.newPlot(                        "be5c6e42-6b05-420d-b641-db9ab4e5e5f7",                        [{"alignmentgroup": "True", "hovertemplate": "Month=January<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "ids": ["January"], "legendgroup": "January", "marker": {"color": "#636efa"}, "name": "January", "offsetgroup": "January", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2000], "xaxis": "x", "y": [19.311], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Month=February<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "ids": ["February"], "legendgroup": "February", "marker": {"color": "#EF553B"}, "name": "February", "offsetgroup": "February", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2000], "xaxis": "x", "y": [14.2357], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Month=March<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "ids": ["March"], "legendgroup": "March", "marker": {"color": "#00cc96"}, "name": "March", "offsetgroup": "March", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2000], "xaxis": "x", "y": [8.70368], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Month=April<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "ids": ["April"], "legendgroup": "April", "marker": {"color": "#ab63fa"}, "name": "April", "offsetgroup": "April", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2000], "xaxis": "x", "y": [3.96081], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Month=May<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "ids": ["May"], "legendgroup": "May", "marker": {"color": "#FFA15A"}, "name": "May", "offsetgroup": "May", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2000], "xaxis": "x", "y": [7.20656], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Month=June<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "ids": ["June"], "legendgroup": "June", "marker": {"color": "#19d3f3"}, "name": "June", "offsetgroup": "June", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2000], "xaxis": "x", "y": [16.5511], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Month=July<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "ids": ["July"], "legendgroup": "July", "marker": {"color": "#FF6692"}, "name": "July", "offsetgroup": "July", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2000], "xaxis": "x", "y": [57.1515], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Month=August<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "ids": ["August"], "legendgroup": "August", "marker": {"color": "#B6E880"}, "name": "August", "offsetgroup": "August", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2000], "xaxis": "x", "y": [32.6807], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Month=September<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "ids": ["September"], "legendgroup": "September", "marker": {"color": "#FF97FF"}, "name": "September", "offsetgroup": "September", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2000], "xaxis": "x", "y": [18.3118], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Month=October<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "ids": ["October"], "legendgroup": "October", "marker": {"color": "#FECB52"}, "n ...

# %% [markdown]
# # Analysis rainfall during Year 1980 to 2000 Using Line Chart

# %%
graph=px.line(data.loc[(data.Year>=1980)].loc[(data.Year<=2000)],x='Year',y='Rainfall-(mm)',color='Month',title='Rainfall in Year 2001 to 2016 ')
graph.show()
# Out:
# <div>                            <div id="f20dfcfc-5e2f-4ed3-b703-e7b1f96c67f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f20dfcfc-5e2f-4ed3-b703-e7b1f96c67f7")) {                    Plotly.newPlot(                        "f20dfcfc-5e2f-4ed3-b703-e7b1f96c67f7",                        [{"hovertemplate": "Month=January<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "legendgroup": "January", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "January", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000], "xaxis": "x", "y": [19.0035, 30.6463, 26.7045, 19.3975, 7.77251, 16.1033, 5.4159, 5.30938, 19.4444, 16.5354, 37.5664, 23.5797, 53.9661, 29.6088, 19.5592, 9.26441, 27.9485, 23.2765, 32.6726, 32.9247, 19.311], "yaxis": "y"}, {"hovertemplate": "Month=February<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "legendgroup": "February", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "February", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000], "xaxis": "x", "y": [29.9826, 32.1889, 43.8462, 27.558, 17.4694, 4.97319, 37.8958, 29.1888, 17.2945, 12.2605, 57.1569, 42.6492, 29.1195, 15.8378, 29.1929, 30.1864, 40.7236, 5.92436, 39.6264, 36.1811, 14.2357], "yaxis": "y"}, {"hovertemplate": "Month=March<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "legendgroup": "March", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "March", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000], "xaxis": "x", "y": [43.5235, 66.5952, 69.4212, 40.6978, 26.3116, 12.0366, 42.6173, 54.0587, 53.0401, 41.2204, 35.7753, 42.4584, 38.7504, 32.1792, 23.597, 23.1022, 44.5704, 38.9486, 37.2368, 23.3168, 8.70368], "yaxis": "y"}, {"hovertemplate": "Month=April<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "legendgroup": "April", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "April", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000], "xaxis": "x", "y": [9.2615, 27.3013, 26.6146, 56.5685, 22.372, 35.0544, 23.7822, 21.1257, 8.47749, 9.66336, 17.4093, 43.043, 40.764, 19.6552, 26.8942, 44.2381, 24.3362, 39.8522, 31.8033, 18.1675, 3.96081], "yaxis": "y"}, {"hovertemplate": "Month=May<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "legendgroup": "May", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "May", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000], "xaxis": "x", "y": [12.7197, 17.4683, 28.7386, 26.2521, 13.4199, 13.6178, 16.0415, 30.0705, 3.33549, 14.575, 12.065, 26.5375, 23.8701, 15.3862, 19.8453, 11.1759, 33.005, 18.4543, 21.8943, 9.97722, 7.20656], "yaxis": "y"}, {"hovertemplate": "Month=June<br>Year=%{x}<br>Rainfall-(mm)=%{y}<extra></extra>", "legendgroup": "June", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "June", "orientation": "v", "showlegend": true, "type": "scatter", "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000], "xaxis": "x", "y": [30.0792, 8.78363, 5.91588, 13.9626, 11.7076, 7.46 ...

# %% [markdown]
# # Comaparison Between rainfall During 1980 to 2000 and 2001 to 2016 in the month of June

# %%
sel=data[{'Year','Rainfall-(mm)','Month'}].loc[(data.Year>=1980)].loc[(data.Year<=2000)].loc[(data.Month=="June")]
graph=px.line(sel,x='Year',y='Rainfall-(mm)',color='Month',range_x=[1979,2001],text='Rainfall-(mm)',title='Rainfall in June Year 1980 to 2000')
graph.update_traces(texttemplate='%{text:.4s}',textposition='top center')
graph.show()
sel1=data[{'Year','Rainfall-(mm)','Month'}].loc[(data.Year>=2001)].loc[(data.Year<=2016)].loc[(data.Month=="June")]
graph1=px.line(sel1,x='Year',y='Rainfall-(mm)',color='Month',range_x=[2000,2017],text='Rainfall-(mm)',title='Rainfall in June during Year 20001 to 2016')
graph1.update_traces(texttemplate='%{text:.4s}',textposition='top center')
graph1.show()
# Out:
# <div>                            <div id="fa95e47d-4a32-4f5a-b257-f81021c50001" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa95e47d-4a32-4f5a-b257-f81021c50001")) {                    Plotly.newPlot(                        "fa95e47d-4a32-4f5a-b257-f81021c50001",                        [{"hovertemplate": "Month=June<br>Year=%{x}<br>Rainfall-(mm)=%{text}<extra></extra>", "legendgroup": "June", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers+text", "name": "June", "orientation": "v", "showlegend": true, "text": [30.0792, 8.78363, 5.91588, 13.9626, 11.7076, 7.46966, 23.4765, 25.6525, 17.9278, 14.3944, 10.1119, 10.7911, 5.56877, 19.6844, 21.5863, 15.1367, 45.5516, 32.5392, 25.044, 9.80438, 16.5511], "textposition": "top center", "texttemplate": "%{text:.4s}", "type": "scatter", "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000], "xaxis": "x", "y": [30.0792, 8.78363, 5.91588, 13.9626, 11.7076, 7.46966, 23.4765, 25.6525, 17.9278, 14.3944, 10.1119, 10.7911, 5.56877, 19.6844, 21.5863, 15.1367, 45.5516, 32.5392, 25.044, 9.80438, 16.5511], "yaxis": "y"}],                        {"legend": {"title": {"text": "Month"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""} ...
# <div>                            <div id="4428160f-fa9c-49a1-8f46-aa945275bc2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4428160f-fa9c-49a1-8f46-aa945275bc2b")) {                    Plotly.newPlot(                        "4428160f-fa9c-49a1-8f46-aa945275bc2b",                        [{"hovertemplate": "Month=June<br>Year=%{x}<br>Rainfall-(mm)=%{text}<extra></extra>", "legendgroup": "June", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers+text", "name": "June", "orientation": "v", "showlegend": true, "text": [42.8297, 25.2618, 13.7782, 19.4183, 7.38339, 19.7032, 37.8191, 26.2055, 18.2574, 25.6214, 16.105, 7.12074, 37.7994, 11.8501, 28.986, 23.6518], "textposition": "top center", "texttemplate": "%{text:.4s}", "type": "scatter", "x": [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], "xaxis": "x", "y": [42.8297, 25.2618, 13.7782, 19.4183, 7.38339, 19.7032, 37.8191, 26.2055, 18.2574, 25.6214, 16.105, 7.12074, 37.7994, 11.8501, 28.986, 23.6518], "yaxis": "y"}],                        {"legend": {"title": {"text": "Month"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333,  ...

# %% [markdown]
# # Comaparison Between rainfall During 1980 to 2000 and 2001 to 2016 in the month of July

# %%
sel=data[{'Year','Rainfall-(mm)','Month'}].loc[(data.Year>=1980)].loc[(data.Year<=2000)].loc[(data.Month=="July")]
graph=px.line(sel,x='Year',y='Rainfall-(mm)',color='Month',range_x=[1979,2001],text='Rainfall-(mm)',title='Rainfall in July Year 1980 to 2000')
graph.update_traces(texttemplate='%{text:.4s}',textposition='top center')
graph.show()
sel1=data[{'Year','Rainfall-(mm)','Month'}].loc[(data.Year>=2001)].loc[(data.Year<=2016)].loc[(data.Month=="July")]
graph1=px.line(sel1,x='Year',y='Rainfall-(mm)',color='Month',range_x=[2000,2017],text='Rainfall-(mm)',title='Rainfall in July during Year 2001 to 2016')
graph1.update_traces(texttemplate='%{text:.4s}',textposition='top center')
graph1.show()
# Out:
# <div>                            <div id="0c058a7e-c0aa-484b-90f3-179c8b215305" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c058a7e-c0aa-484b-90f3-179c8b215305")) {                    Plotly.newPlot(                        "0c058a7e-c0aa-484b-90f3-179c8b215305",                        [{"hovertemplate": "Month=July<br>Year=%{x}<br>Rainfall-(mm)=%{text}<extra></extra>", "legendgroup": "July", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers+text", "name": "July", "orientation": "v", "showlegend": true, "text": [62.1531, 84.8033, 29.9389, 58.5618, 52.6636, 57.1505, 47.7411, 19.9808, 100.4, 111.255, 27.8177, 20.3078, 54.8721, 73.2203, 116.973, 97.9396, 37.5503, 61.0494, 49.0101, 38.2667, 57.1515], "textposition": "top center", "texttemplate": "%{text:.4s}", "type": "scatter", "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000], "xaxis": "x", "y": [62.1531, 84.8033, 29.9389, 58.5618, 52.6636, 57.1505, 47.7411, 19.9808, 100.4, 111.255, 27.8177, 20.3078, 54.8721, 73.2203, 116.973, 97.9396, 37.5503, 61.0494, 49.0101, 38.2667, 57.1515], "yaxis": "y"}],                        {"legend": {"title": {"text": "Month"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""},  ...
# <div>                            <div id="e2cb9c22-3bfe-4f5c-a896-a4fa184e83c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2cb9c22-3bfe-4f5c-a896-a4fa184e83c4")) {                    Plotly.newPlot(                        "e2cb9c22-3bfe-4f5c-a896-a4fa184e83c4",                        [{"hovertemplate": "Month=July<br>Year=%{x}<br>Rainfall-(mm)=%{text}<extra></extra>", "legendgroup": "July", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers+text", "name": "July", "orientation": "v", "showlegend": true, "text": [70.3518, 11.4863, 106.583, 23.6964, 56.0509, 56.8962, 60.6515, 48.5093, 50.6734, 105.22, 37.5047, 26.7597, 45.7747, 30.8147, 72.6114, 56.4818], "textposition": "top center", "texttemplate": "%{text:.4s}", "type": "scatter", "x": [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], "xaxis": "x", "y": [70.3518, 11.4863, 106.583, 23.6964, 56.0509, 56.8962, 60.6515, 48.5093, 50.6734, 105.22, 37.5047, 26.7597, 45.7747, 30.8147, 72.6114, 56.4818], "yaxis": "y"}],                        {"legend": {"title": {"text": "Month"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333 ...

# %% [markdown]
# # Comaparison Between rainfall During 1980 to 2000 and 2001 to 2016 in the month of August

# %%
sel=data[{'Year','Rainfall-(mm)','Month'}].loc[(data.Year>=1980)].loc[(data.Year<=2000)].loc[(data.Month=="August")]
graph=px.line(sel,x='Year',y='Rainfall-(mm)',color='Month',range_x=[1979,2001],text='Rainfall-(mm)',title='Rainfall in August Year 1980 to 2000')
graph.update_traces(texttemplate='%{text:.4s}',textposition='top center')
graph.show()
sel1=data[{'Year','Rainfall-(mm)','Month'}].loc[(data.Year>=2001)].loc[(data.Year<=2016)].loc[(data.Month=="August")]
graph1=px.line(sel1,x='Year',y='Rainfall-(mm)',color='Month',range_x=[2000,2017],text='Rainfall-(mm)',title='Rainfall in August during Year 2001 to 2016')
graph1.update_traces(texttemplate='%{text:.4s}',textposition='top center')
graph1.show()
# Out:
# <div>                            <div id="41d62d22-e7c5-4f77-bade-69425238863b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41d62d22-e7c5-4f77-bade-69425238863b")) {                    Plotly.newPlot(                        "41d62d22-e7c5-4f77-bade-69425238863b",                        [{"hovertemplate": "Month=August<br>Year=%{x}<br>Rainfall-(mm)=%{text}<extra></extra>", "legendgroup": "August", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers+text", "name": "August", "orientation": "v", "showlegend": true, "text": [34.2454, 38.2932, 58.7005, 105.788, 80.2843, 54.7685, 94.5262, 23.3548, 57.4279, 48.2808, 100.131, 33.49, 69.1804, 11.8972, 83.9455, 58.5468, 54.5763, 84.8412, 28.9697, 45.1223, 32.6807], "textposition": "top center", "texttemplate": "%{text:.4s}", "type": "scatter", "x": [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000], "xaxis": "x", "y": [34.2454, 38.2932, 58.7005, 105.788, 80.2843, 54.7685, 94.5262, 23.3548, 57.4279, 48.2808, 100.131, 33.49, 69.1804, 11.8972, 83.9455, 58.5468, 54.5763, 84.8412, 28.9697, 45.1223, 32.6807], "yaxis": "y"}],                        {"legend": {"title": {"text": "Month"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ...
# <div>                            <div id="8c28cc6e-f27e-4651-b483-10202951aea7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c28cc6e-f27e-4651-b483-10202951aea7")) {                    Plotly.newPlot(                        "8c28cc6e-f27e-4651-b483-10202951aea7",                        [{"hovertemplate": "Month=August<br>Year=%{x}<br>Rainfall-(mm)=%{text}<extra></extra>", "legendgroup": "August", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines+markers+text", "name": "August", "orientation": "v", "showlegend": true, "text": [28.1631, 34.2267, 67.9582, 55.6869, 27.6218, 92.8018, 42.5053, 90.4538, 30.7856, 113.186, 80.6547, 45.5465, 72.268, 30.2337, 69.5808, 60.6061], "textposition": "top center", "texttemplate": "%{text:.4s}", "type": "scatter", "x": [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], "xaxis": "x", "y": [28.1631, 34.2267, 67.9582, 55.6869, 27.6218, 92.8018, 42.5053, 90.4538, 30.7856, 113.186, 80.6547, 45.5465, 72.268, 30.2337, 69.5808, 60.6061], "yaxis": "y"}],                        {"legend": {"title": {"text": "Month"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333 ...

# %% [markdown]
# # Number of Percent Rainfall during Year 2000 to 2016

# %%
sel=data[{'Rainfall-(mm)','Year'}].loc[(data.Year>=2000)]

fig=px.pie(sel,values='Rainfall-(mm)',color='Year',names='Year',labels='Year',width=800,height=600,hole=0.5,title='Number of Percent Rainfall  Year during 2000 to 2016')
fig.show()
# Out:
# <div>                            <div id="c778e117-b319-4668-a7ea-52d20795301f" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c778e117-b319-4668-a7ea-52d20795301f")) {                    Plotly.newPlot(                        "c778e117-b319-4668-a7ea-52d20795301f",                        [{"customdata": [[2000], [2000], [2000], [2000], [2000], [2000], [2000], [2000], [2000], [2000], [2000], [2000], [2001], [2001], [2001], [2001], [2001], [2001], [2001], [2001], [2001], [2001], [2001], [2001], [2002], [2002], [2002], [2002], [2002], [2002], [2002], [2002], [2002], [2002], [2002], [2002], [2003], [2003], [2003], [2003], [2003], [2003], [2003], [2003], [2003], [2003], [2003], [2003], [2004], [2004], [2004], [2004], [2004], [2004], [2004], [2004], [2004], [2004], [2004], [2004], [2005], [2005], [2005], [2005], [2005], [2005], [2005], [2005], [2005], [2005], [2005], [2005], [2006], [2006], [2006], [2006], [2006], [2006], [2006], [2006], [2006], [2006], [2006], [2006], [2007], [2007], [2007], [2007], [2007], [2007], [2007], [2007], [2007], [2007], [2007], [2007], [2008], [2008], [2008], [2008], [2008], [2008], [2008], [2008], [2008], [2008], [2008], [2008], [2009], [2009], [2009], [2009], [2009], [2009], [2009], [2009], [2009], [2009], [2009], [2009], [2010], [2010], [2010], [2010], [2010], [2010], [2010], [2010], [2010], [2010], [2010], [2010], [2011], [2011], [2011], [2011], [2011], [2011], [2011], [2011], [2011], [2011], [2011], [2011], [2012], [2012], [2012], [2012], [2012], [2012], [2012], [2012], [2012], [2012], [2012], [2012], [2013], [2013], [2013], [2013], [2013], [2013], [2013], [2013], [2013], [2013], [2013], [2013], [2014], [2014], [2014], [2014], [2014], [2014], [2014], [2014], [2014], [2014], [2014], [2014], [2015], [2015], [2015], [2015], [2015], [2015], [2015], [2015], [2015], [2015], [2015], [2015], [2016], [2016], [2016], [2016], [2016], [2016], [2016], [2016], [2016], [2016], [2016], [2016]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.5, "hovertemplate": "Year=%{customdata[0]}<br>Rainfall-(mm)=%{value}<extra></extra>", "labels": [2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2000, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2002, 2003, 2003, 2003, 2003, 2003, 2003, 2003, 2003, 2003, 2003, 2003, 2003, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016], "legendgroup": "", "marker": {"colors": ["#636efa", "#636efa", "#636efa", "#636efa", "#636efa", "#636efa", "#636efa", "#636efa", "#636efa", "#636efa", "#636efa", "#636efa", "#EF553B", "#EF553B", "#EF553B", "#EF553B", "#EF553B", "#EF553B", "#EF553B", "#EF553B", "#EF553B", "#EF553B", "#EF553B", "#EF553B", "#00cc96", "#00cc96", "#00cc96", "#00cc96", "#00cc96", "#00cc96", "#00cc96", "#00cc96", "#00cc96", "#00cc96", "#00cc96", "#00cc96", "#ab ...
